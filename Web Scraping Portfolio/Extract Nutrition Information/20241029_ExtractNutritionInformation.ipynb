# %%
'''
匯入套件
'''
# 操作 browser 的 API
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# ChromeDriver 的下載管理工具
from webdriver_manager.chrome import ChromeDriverManager

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 取得系統時間的工具
from datetime import datetime

# 強制停止/強制等待 (程式執行期間休息一下)
from time import sleep

# 處理下拉式選單的工具
from selenium.webdriver.support.ui import Select

import pprint
import os

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                # 不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         # 最大化視窗
my_options.add_argument("--incognito")               # 開啟無痕模式
my_options.add_argument("--disable-popup-blocking")  # 禁用彈出攔截
my_options.add_argument("--disable-notifications")   # 取消通知
my_options.add_argument(f'--user-agent={ua.random}') # (Optional)加入 User-Agent

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options,
)

# 儲存資料的變數
list_data = []

# 走訪網址
url = 'https://consumer.fda.gov.tw/Food/TFND.aspx?nodeID=178'
type_index = 18
keyword = '冷凍'

# %%
#visit url page
def visit():
    driver.get(url);

#select drop-down menu:
def setDropDownMenu(type_index):
    try:
        #強制等待
        sleep(1)

        # 選擇食物類別
        type = Select(driver.find_element(By.CSS_SELECTOR, 'li > select'))
        type.select_by_index(type_index)
                      
        # 強制等待
        sleep(2)
    except Exception as err:
        print(str(err))

def key_in_search(keyword):
    try:
        search_box = driver.find_element(
            By.CSS_SELECTOR, 'input#ctl00_content_SelectK'
        )
        search_box.send_keys(keyword)

        # 強制等待
        sleep(1)
        
        # 按下查詢
        driver.find_element(
            By.CSS_SELECTOR, 'input#ctl00_content_searchBut'
        ).click()

        # 強制等待
        sleep(2)
    except Exception as err:
            print(str(err))

visit()
setDropDownMenu(type_index)
key_in_search(keyword)

# %% [markdown]
# ## 開啟分頁

# %%
no_of_handles = int(driver.find_element(
            By.CSS_SELECTOR, '#ctl00_content_ListPanel div a:nth-child(7)'
        ).get_attribute('href')[-1])-1

# 連續開 3 個分頁 (javascript)
for i in range(no_of_handles):
    driver.execute_script(f'window.open("");')

# %%
# 切換到初始分頁 (索引為 0)
driver.switch_to.window(driver.window_handles[0])

# %%
# 將所有 tabs 轉址，以便取得對應列表; 0 不變
for index in range(1, len(driver.window_handles)):
    try:
        #change tabs
        driver.switch_to.window(driver.window_handles[index])
        # 使分頁自動連結到指定網址 (此時的 drive 變數指向切後的分頁)
        driver.get(f'https://consumer.fda.gov.tw/Food/TFND.aspx?nodeID=178&t={type_index}&k={keyword}&p={index}')  
        
        # Use explicit wait instead of sleep
        WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, 'td[data-th="樣品名稱"]>a'))
        )
    except Exception as e:
            print(f"Error loading page at tab {index}: {e}")

# %%
# 取得分頁列表
for index in range(1, len(driver.window_handles)):
    try:
        #change tabs
        driver.switch_to.window(driver.window_handles[index])

        #取得列表連結與內文
        items = driver.find_elements(By.CSS_SELECTOR, 'td[data-th="樣品名稱"]>a')
        for a in items:
            list_data.append({
                'Food': a.get_attribute('innerText'),
                'Link': a.get_attribute('href')
            })

    except Exception as e:
        print(f"Error extracting data at tab {index}: {e}")

# %%
#view list
list_data
# Out:
# [{'Food': '冷凍火腿炒飯',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1753'},
#  {'Food': '冷凍蝦仁炒飯',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1770'},
#  {'Food': '冷凍筒仔米糕',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1797'},
#  {'Food': '冷凍芝麻湯圓',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1755'},
#  {'Food': '冷凍花生湯圓',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1756'},
#  {'Food': '冷凍豬肉湯圓',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1774'},
#  {'Food': '冷凍烏龍麵',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1972'},
#  {'Food': '冷凍牛肉水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1784'},
#  {'Food': '冷凍豬肉水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1771'},
#  {'Food': '冷凍豬肉韭菜水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1766'},
#  {'Food': '冷凍豬肉蟹黃水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1792'},
#  {'Food': '冷凍香菇雞肉水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1839'},
#  {'Food': '冷凍素食水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1761'},
#  {'Food': '冷凍鮪魚水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1840'},
#  {'Food': '冷凍豬肉熟水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1794'},
#  {'Food': '冷凍素食熟水餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1795'},
#  {'Food': '冷凍冬菜蝦仁餛飩',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1754'},
#  {'Food': '冷凍豬肉餛飩',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1773'},
#  {'Food': '冷凍菜肉餛飩',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1764'},
#  {'Food': '冷凍叉燒包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1692'},
#  {'Food': '冷凍酸菜焢肉包子',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1842'},
#  {'Food': '冷凍芋泥包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1694'},
#  {'Food': '冷凍豆沙包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1693'},
#  {'Food': '冷凍芝麻包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1695'},
#  {'Food': '冷凍蓮蓉包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1697'},
#  {'Food': '冷凍叉燒包子',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1837'},
#  {'Food': '冷凍牛肉包子',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1836'},
#  {'Food': '冷凍豬肉包子',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1698'},
#  {'Food': '冷凍豬肉湯包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1699'},
#  {'Food': '冷凍素菜包子',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1696'},
#  {'Food': '冷凍白饅頭',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1835'},
#  {'Food': '冷凍銀絲卷(奶黃)',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1793'},
#  {'Food': '冷凍披薩(黑胡椒火腿)',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1791'},
#  {'Food': '冷凍蔥油餅',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1765'},
#  {'Food': '冷凍蛋餅皮',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1944'},
#  {'Food': '冷凍燒賣',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1702'},
#  {'Food': '冷凍水晶包',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1832'},
#  {'Food': '冷凍,水晶餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1947'},
#  {'Food': '冷凍春捲',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1829'},
#  {'Food': '冷凍可樂餅(奶汁)',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1787'},
#  {'Food': '冷凍甘薯條',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=129'},
#  {'Food': '冷凍馬鈴薯條',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=128'},
#  {'Food': '冷凍洋蔥圈',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1838'},
#  {'Food': '冷凍豆腐',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=780'},
#  {'Food': '冷凍素雞塊',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1801'},
#  {'Food': '冷凍小香腸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1790'},
#  {'Food': '冷凍珍珠丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1759'},
#  {'Food': '冷凍貢丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1781'},
#  {'Food': '冷凍雞肉丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1833'},
#  {'Food': '冷凍牛肉漢堡肉',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1951'},
#  {'Food': '冷凍雞塊',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1777'},
#  {'Food': '冷凍咕咾肉',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1757'},
#  {'Food': '冷凍花枝丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1799'},
#  {'Food': '冷凍虱目魚丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1758'},
#  {'Food': '冷凍文蛤丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1844'},
#  {'Food': '冷凍旗魚丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1762'},
#  {'Food': '冷凍鱈魚丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1778'},
#  {'Food': '冷凍蝦丸',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1768'},
#  {'Food': '冷凍花枝排',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1953'},
#  {'Food': '冷凍鮪排',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1775'},
#  {'Food': '冷凍蝦餅',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1760'},
#  {'Food': '冷凍干貝酥',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1830'},
#  {'Food': '冷凍花枝塊',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1789'},
#  {'Food': '冷凍旗魚塊',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1798'},
#  {'Food': '冷凍蚵捲',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1831'},
#  {'Food': '冷凍魚捲',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1763'},
#  {'Food': '冷凍蝦捲',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1952'},
#  {'Food': '冷凍魷魚圈',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1769'},
#  {'Food': '冷凍花枝餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1796'},
#  {'Food': '冷凍香菇餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1785'},
#  {'Food': '冷凍蛋餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1788'},
#  {'Food': '冷凍雪螺餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1786'},
#  {'Food': '冷凍魚餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1780'},
#  {'Food': '冷凍蝦餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1779'},
#  {'Food': '冷凍燕餃',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1772'},
#  {'Food': '冷凍蟹味棒',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1776'},
#  {'Food': '冷凍魚卵卷',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1783'},
#  {'Food': '冷凍花枝漿',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=2100'},
#  {'Food': '冷凍花枝羹',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1782'},
#  {'Food': '冷凍烤雞翅',
#   'Link': 'https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=975'}]

# %% [markdown]
# ## 拿資料

# %%
# 儲存食物資料跟營養成分
food_info = []
food_nutr = []
selected_items = []

# %%
def extract_food_info():
    #driver.get(url_page)
    info = {
        'Food Category 食品分類': driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbFoodCategoryName').get_attribute('innerText'),
        'Data Type 資料類別': driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbDataType').get_attribute('innerText'),
        #'Int No 整合編號': driver.find_elements(By.CSS_SELECTOR, '#ctl00_content_lbIntNo').get_attribute('innerText'),
        'Food Name 樣品名稱': driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbFoodName').get_attribute('innerText'),
        'Other Name 俗名': driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbTrivialName').get_attribute('innerText'),
        'English Name 樣品英文名稱': driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbFoodEName').get_attribute('innerText'),
        'Content 內容物描述': driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbContent').get_attribute('innerText')
    }

    food_info.append(info)

'''
extract_food_info()
'''
# Out:
# '\nextract_food_info()\n'

# %%
# Loop through each row and extract '分析項' and '每100克含量'
def extract_food_nutr():
    """Extract food name and nutrition data for selected items from the TFDA website."""
    try:
        # Define the specific '分析項' you're interested in
        selected_items = ["熱量", "粗蛋白", "粗脂肪", "飽和脂肪", "總碳水化合物", "膳食纖維", "糖質總量", "鈉", "膽固醇", "反式脂肪"]

        # Locate rows in a table
        trs = driver.find_elements(By.CSS_SELECTOR, 'table.rwd-table > tbody > tr')    # append food name
        
        # Append food name
        nutr = []
        food_name = driver.find_element(By.CSS_SELECTOR, '#ctl00_content_lbFoodName').get_attribute('innerText')
        nutr.append(food_name)
        for tr in trs:
            tds = tr.find_elements(By.CSS_SELECTOR, 'td.txt_C')
            if len(tds) >= 2:  # Check if there are at least 2 <td> elements
                analysis_item = tds[1].text.strip()
                # Skip the '修正熱量' column
                if analysis_item == "修正熱量":
                    continue  # Skip this iteration if it's "修正熱量"
                if analysis_item in selected_items:
                    # Extract based on selected items
                    nutr.append(tds[3].text.strip())
                    
        # Append the extracted info
        food_nutr.append(nutr)

    except Exception as e:
        print(f"Error extracting data: {e}")
        return []

#execute function and print the nutrition data dictionary
#extract_food_nutr()
#pprint.pprint(food_nutr)
# Out:
# " \n        #取得列表內文\n        analysis_item = row.find_elements(By.CSS_SELECTOR, 'td:nth-child(2)').get_attribute('innerText')\n        if analysis_item in selected_items:\n            content_per_100g = row.find_element(By.CSS_SELECTOR, 'td:nth-child(4)').text.strip()\n\n            # Append the item and its content per 100g to the dictionary\n            food_nutr[analysis_item] = content_per_100g\n"

# %%
max_tabs = len(driver.window_handles)

#iterate over list_data (all of frozen food links)
for index, item in enumerate(list_data):
    url_link = item['Link']
    food_name = item['Food']

    # Switch tabs
    tab_index = (index % max_tabs)  # Cycle through tabs
    driver.switch_to.window(
            driver.window_handles[tab_index]
    )
    
    # 使分頁自動連結到指定網址 (此時的 drive 變數指向切後的分頁)
    driver.get(url_link)
        
    extract_food_info()
    extract_food_nutr()

    # You can also process or store the food_name if needed
    print(f"Processing food: {food_name} at {url_link}")
        
    sleep(3)

#check output
pprint.pprint(food_info, sort_dicts=False)
pprint.pprint(food_nutr)
# Out:
# Processing food: 冷凍火腿炒飯 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1753
# Processing food: 冷凍蝦仁炒飯 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1770
# Processing food: 冷凍筒仔米糕 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1797
# Processing food: 冷凍芝麻湯圓 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1755
# Processing food: 冷凍花生湯圓 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1756
# Processing food: 冷凍豬肉湯圓 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1774
# Processing food: 冷凍烏龍麵 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1972
# Processing food: 冷凍牛肉水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1784
# Processing food: 冷凍豬肉水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1771
# Processing food: 冷凍豬肉韭菜水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1766
# Processing food: 冷凍豬肉蟹黃水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1792
# Processing food: 冷凍香菇雞肉水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1839
# Processing food: 冷凍素食水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1761
# Processing food: 冷凍鮪魚水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1840
# Processing food: 冷凍豬肉熟水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1794
# Processing food: 冷凍素食熟水餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1795
# Processing food: 冷凍冬菜蝦仁餛飩 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1754
# Processing food: 冷凍豬肉餛飩 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1773
# Processing food: 冷凍菜肉餛飩 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1764
# Processing food: 冷凍叉燒包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1692
# Processing food: 冷凍酸菜焢肉包子 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1842
# Processing food: 冷凍芋泥包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1694
# Processing food: 冷凍豆沙包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1693
# Processing food: 冷凍芝麻包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1695
# Processing food: 冷凍蓮蓉包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1697
# Processing food: 冷凍叉燒包子 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1837
# Processing food: 冷凍牛肉包子 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1836
# Processing food: 冷凍豬肉包子 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1698
# Processing food: 冷凍豬肉湯包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1699
# Processing food: 冷凍素菜包子 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1696
# Processing food: 冷凍白饅頭 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1835
# Processing food: 冷凍銀絲卷(奶黃) at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1793
# Processing food: 冷凍披薩(黑胡椒火腿) at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1791
# Processing food: 冷凍蔥油餅 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1765
# Processing food: 冷凍蛋餅皮 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1944
# Processing food: 冷凍燒賣 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1702
# Processing food: 冷凍水晶包 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1832
# Processing food: 冷凍,水晶餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1947
# Processing food: 冷凍春捲 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1829
# Processing food: 冷凍可樂餅(奶汁) at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1787
# Processing food: 冷凍甘薯條 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=129
# Processing food: 冷凍馬鈴薯條 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=128
# Processing food: 冷凍洋蔥圈 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1838
# Processing food: 冷凍豆腐 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=780
# Processing food: 冷凍素雞塊 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1801
# Processing food: 冷凍小香腸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1790
# Processing food: 冷凍珍珠丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1759
# Processing food: 冷凍貢丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1781
# Processing food: 冷凍雞肉丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1833
# Processing food: 冷凍牛肉漢堡肉 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1951
# Processing food: 冷凍雞塊 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1777
# Processing food: 冷凍咕咾肉 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1757
# Processing food: 冷凍花枝丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1799
# Processing food: 冷凍虱目魚丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1758
# Processing food: 冷凍文蛤丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1844
# Processing food: 冷凍旗魚丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1762
# Processing food: 冷凍鱈魚丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1778
# Processing food: 冷凍蝦丸 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1768
# Processing food: 冷凍花枝排 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1953
# Processing food: 冷凍鮪排 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1775
# Processing food: 冷凍蝦餅 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1760
# Processing food: 冷凍干貝酥 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1830
# Processing food: 冷凍花枝塊 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1789
# Processing food: 冷凍旗魚塊 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1798
# Processing food: 冷凍蚵捲 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1831
# Processing food: 冷凍魚捲 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1763
# Processing food: 冷凍蝦捲 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1952
# Processing food: 冷凍魷魚圈 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1769
# Processing food: 冷凍花枝餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1796
# Processing food: 冷凍香菇餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1785
# Processing food: 冷凍蛋餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1788
# Processing food: 冷凍雪螺餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1786
# Processing food: 冷凍魚餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1780
# Processing food: 冷凍蝦餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1779
# Processing food: 冷凍燕餃 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1772
# Processing food: 冷凍蟹味棒 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1776
# Processing food: 冷凍魚卵卷 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1783
# Processing food: 冷凍花枝漿 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=2100
# Processing food: 冷凍花枝羹 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=1782
# Processing food: 冷凍烤雞翅 at https://consumer.fda.gov.tw/Food/tfndDetail.aspx?nodeID=178&f=0&id=975
# [{'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍火腿炒飯',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Fried rice',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(米,火腿,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蝦仁炒飯',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Fried rice',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(米,蝦仁,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍筒仔米糕',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(糯米,香菇,豬前腿肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍芝麻湯圓',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(糯米,芝麻粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花生湯圓',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(糯米,花生粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉湯圓',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(糯米,豬前腿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍烏龍麵',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:濕麵條(小麥粉,澱粉,鹽等),冷凍製品; 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍牛肉水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: beef',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(牛肉,洋蔥,麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: pork',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,鮮肉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉韭菜水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: pork and leek',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,鮮肉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉蟹黃水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍香菇雞肉水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: marshroom, chicken',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(雞肉,香菇,豬肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍素食水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: vegetarian',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,冬粉,蔬菜,腐皮等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍鮪魚水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: tuna',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,鮪魚,豬肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉熟水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: pork, cooked',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,麵粉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍素食熟水餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Dumpling: vegetarian, cooked',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(素肉,麵粉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍冬菜蝦仁餛飩',
#   'Other Name 俗名': '雲吞',
#   'English Name 樣品英文名稱': 'Wonton: cabbage and shrimp',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(蝦仁,魚肉,蔬菜,麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉餛飩',
#   'Other Name 俗名': '雲吞',
#   'English Name 樣品英文名稱': 'Wonton: pork',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,鮮肉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍菜肉餛飩',
#   'Other Name 俗名': '雲吞',
#   'English Name 樣品英文名稱': 'Wonton: vegetable and pork',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬腿肉,麵粉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍叉燒包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍酸菜焢肉包子',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,豬肉,酸菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍芋泥包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Taro paste bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,芋頭等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豆沙包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Red bean paste bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,紅豆沙等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍芝麻包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Sesame bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,芝麻粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蓮蓉包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Lotus seed paste bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝; 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍叉燒包子',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(叉燒肉,雞蛋,麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍牛肉包子',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Beef bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(牛肉,麵粉,雞蛋等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉包子',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Pork bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,麵粉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豬肉湯包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Pork bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬後腿肉,麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍素菜包子',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Vegetable bun',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍白饅頭',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍銀絲卷(奶黃)',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,奶黃醬等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍披薩(黑胡椒火腿)',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Pizza',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,奶油等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蔥油餅',
#   'Other Name 俗名': '蔥油派',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,蔥,雞蛋等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蛋餅皮',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,澱粉,蔥,植物油,豬油,白芝麻,鹽,糖等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍燒賣',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬後腿肉,蔬菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍水晶包',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,蝦仁,澱粉,香菇,高麗菜等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍,水晶餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,沙拉油,白蘿蔔乾,油蔥,醬油,調味料等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍春捲',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Spring roll',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(麵粉,椰菜,筍,青豆,蘑菇等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍可樂餅(奶汁)',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(牛奶,洋蔥,火腿,玉米等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍甘薯條',
#   'Other Name 俗名': '薯條',
#   'English Name 樣品英文名稱': 'French fries: sweet potato',
#   'Content 內容物描述': '樣品狀態:冷凍包裝; 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍馬鈴薯條',
#   'Other Name 俗名': '薯條',
#   'English Name 樣品英文名稱': 'French fries: potato',
#   'Content 內容物描述': '樣品狀態:冷凍包裝; 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍洋蔥圈',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Onion ring',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(洋蔥,麵粉,玉米粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍豆腐',
#   'Other Name 俗名': '凍豆腐',
#   'English Name 樣品英文名稱': 'Bean curd: frozen',
#   'Content 內容物描述': '樣品狀態:冷凍包裝; 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍素雞塊',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(黃豆,大豆蛋白,麵衣等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍小香腸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Sausage',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,牛肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍珍珠丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,米等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍貢丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Meatball',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬後腿肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍雞肉丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(雞肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍牛肉漢堡肉',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(牛肉,禽肉,麵包粉,洋蔥,蕃茄醬,磷酸鹽類等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍雞塊',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Chicken nugget',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(雞胸肉,腿肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍咕咾肉',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,洋蔥,青椒等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花枝丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(花枝肉,板油,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍虱目魚丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Milkfish ball',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(虱目魚,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍文蛤丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Clam ball',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(文蛤,虱目魚肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍旗魚丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Swordfish ball',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(旗魚肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍鱈魚丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Codfish ball',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(鱈魚,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蝦丸',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Shrimp ball',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(蝦肉,魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花枝排',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(花枝肉,魚漿,洋蔥,麵包屑,澱粉,調味料,磷酸鹽等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍鮪排',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(鮪魚,魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蝦餅',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Shrimp croquette',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(蝦仁,鱈魚,馬蹄,豌豆,裹麵等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍干貝酥',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(鱈魚肉,卵白,澱粉,干貝及抽出物等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花枝塊',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(花枝,魷魚,魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍旗魚塊',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(旗魚肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蚵捲',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(蚵,韭菜,豆皮等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍魚捲',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(旗魚,鱈魚,馬蹄,裹麵等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蝦捲',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(魚漿,蝦,豬脂,馬蹄,紅蘿蔔,蒜頭,蔥,豆皮等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍魷魚圈',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Squid ring',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(魷魚,魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花枝餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(海饅,花枝肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍香菇餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬肉,香菇,鱈魚等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蛋餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(雞蛋,豬肉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍雪螺餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(魚漿,雪螺,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍魚餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(海鰻,豬肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蝦餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(海鰻,蝦仁,豬肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍燕餃',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(豬後腿肉,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍蟹味棒',
#   'Other Name 俗名': '蟹肉棒',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍魚卵卷',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Fish roe roll',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(魚卵,魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花枝漿',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': '',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(花枝塊,調味品,澱粉等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍花枝羹',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Cuttlefish potage',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(花枝,魚漿等); 前處理描述:混合均勻打碎'},
#  {'Food Category 食品分類': '加工調理食品及其他類',
#   'Data Type 資料類別': '樣品基本資料',
#   'Food Name 樣品名稱': '冷凍烤雞翅',
#   'Other Name 俗名': '',
#   'English Name 樣品英文名稱': 'Chicken: wing, frozen, roasted',
#   'Content 內容物描述': '樣品狀態:冷凍包裝(雞翅,植物油等); 前處理描述:去骨,混合均勻打碎'}]
# [['冷凍火腿炒飯', '189', '5.0', '5.6', '1.1', '29.7', '2.0', '', '220', '37', ''],
#  ['冷凍蝦仁炒飯',
#   '148',
#   '4.7',
#   '3.4',
#   '0.5',
#   '24.6',
#   '2.7',
#   '1.3',
#   '222',
#   '11',
#   '13.41'],
#  ['冷凍筒仔米糕', '212', '6.5', '5.8', '2.2', '33.6', '0.7', '', '331', '13', ''],
#  ['冷凍芝麻湯圓',
#   '352',
#   '4.8',
#   '16.3',
#   '6.6',
#   '46.7',
#   '0.9',
#   '9.7',
#   '3',
#   '0',
#   '69.29'],
#  ['冷凍花生湯圓',
#   '350',
#   '5.2',
#   '15.6',
#   '7.3',
#   '47.1',
#   '0.6',
#   '9.8',
#   '6',
#   '0',
#   '66.28'],
#  ['冷凍豬肉湯圓',
#   '281',
#   '6.5',
#   '12.1',
#   '5.1',
#   '36.6',
#   '0.4',
#   '1.8',
#   '210',
#   '14',
#   '45.10'],
#  ['冷凍烏龍麵',
#   '129',
#   '3.4',
#   '0.3',
#   '0.1',
#   '28.2',
#   '1.5',
#   '0.4',
#   '192',
#   '0',
#   '0.00'],
#  ['冷凍牛肉水餃',
#   '215',
#   '8.9',
#   '9.7',
#   '3.3',
#   '23.1',
#   '1.2',
#   '2.6',
#   '383',
#   '18',
#   '68.08'],
#  ['冷凍豬肉水餃', '208', '8.1', '9.7', '3.4', '22.1', '0.9', '', '447', '25', ''],
#  ['冷凍豬肉韭菜水餃',
#   '229',
#   '8.4',
#   '11.5',
#   '4.2',
#   '23.0',
#   '1.8',
#   '1.8',
#   '439',
#   '31',
#   '32.38'],
#  ['冷凍豬肉蟹黃水餃', '223', '7.8', '9.8', '3.0', '26.0', '1.4', '', '472', '17', ''],
#  ['冷凍香菇雞肉水餃', '221', '9.5', '10.2', '3.5', '22.7', '2.3', '', '350', '17', ''],
#  ['冷凍素食水餃',
#   '175',
#   '8.7',
#   '4.1',
#   '1.1',
#   '25.8',
#   '2.8',
#   '3.2',
#   '369',
#   '0',
#   '37.66'],
#  ['冷凍鮪魚水餃', '196', '9.0', '8.5', '3.3', '20.8', '1.3', '', '275', '19', ''],
#  ['冷凍豬肉熟水餃',
#   '235',
#   '7.2',
#   '10.1',
#   '3.5',
#   '28.9',
#   '2.1',
#   '1.0',
#   '333',
#   '17',
#   '26.95'],
#  ['冷凍素食熟水餃',
#   '209',
#   '7.2',
#   '5.4',
#   '0.9',
#   '32.9',
#   '2.3',
#   '2.8',
#   '491',
#   '',
#   '47.17'],
#  ['冷凍冬菜蝦仁餛飩',
#   '191',
#   '9.1',
#   '6.3',
#   '2.1',
#   '24.5',
#   '2.3',
#   '1.6',
#   '316',
#   '44',
#   '39.61'],
#  ['冷凍豬肉餛飩',
#   '240',
#   '11.1',
#   '12.6',
#   '4.5',
#   '20.5',
#   '2.8',
#   '1.9',
#   '428',
#   '24',
#   '54.93'],
#  ['冷凍菜肉餛飩',
#   '236',
#   '9.1',
#   '16.3',
#   '5.7',
#   '13.3',
#   '4.2',
#   '0.9',
#   '693',
#   '',
#   '67.57'],
#  ['冷凍叉燒包',
#   '266',
#   '8.8',
#   '4.8',
#   '1.7',
#   '47.0',
#   '1.3',
#   '14.8',
#   '167',
#   '12',
#   '7.03'],
#  ['冷凍酸菜焢肉包子', '301', '8.6', '13.1', '5.2', '37.2', '2.1', '', '343', '23', ''],
#  ['冷凍芋泥包',
#   '263',
#   '6.6',
#   '3.6',
#   '1.4',
#   '51.1',
#   '2.4',
#   '11.6',
#   '46',
#   '0',
#   '25.47'],
#  ['冷凍豆沙包', '247', '7.4', '1.1', '0.5', '51.8', '1.7', '13.2', '60', '', '3.54'],
#  ['冷凍芝麻包',
#   '341',
#   '7.2',
#   '11.7',
#   '4.4',
#   '51.7',
#   '0.6',
#   '11.4',
#   '24',
#   '9',
#   '28.01'],
#  ['冷凍蓮蓉包', '292', '7.9', '5.5', '2.3', '52.8', '2.4', '', '82', '7', ''],
#  ['冷凍叉燒包子',
#   '267',
#   '7.1',
#   '6.1',
#   '2.1',
#   '46.0',
#   '2.3',
#   '9.8',
#   '210',
#   '9',
#   '14.33'],
#  ['冷凍牛肉包子', '269', '10.8', '4.6', '2.5', '46.1', '1.8', '', '261', '16', ''],
#  ['冷凍豬肉包子',
#   '266',
#   '7.6',
#   '9.2',
#   '3.5',
#   '38.2',
#   '1.5',
#   '6.4',
#   '230',
#   '14',
#   '8.72'],
#  ['冷凍豬肉湯包',
#   '235',
#   '10.1',
#   '14.3',
#   '4.9',
#   '16.3',
#   '3.0',
#   '1.6',
#   '447',
#   '36',
#   '82.96'],
#  ['冷凍素菜包子',
#   '234',
#   '8.6',
#   '3.8',
#   '1.4',
#   '41.4',
#   '1.1',
#   '3.7',
#   '244',
#   '',
#   '22.18'],
#  ['冷凍白饅頭', '279', '7.4', '2.4', '1.4', '57.0', '2.3', '', '91', '', ''],
#  ['冷凍銀絲卷(奶黃)', '283', '8.9', '3.3', '1.6', '54.5', '2.2', '', '11', '0', ''],
#  ['冷凍披薩(黑胡椒火腿)',
#   '210',
#   '9.3',
#   '6.8',
#   '3.9',
#   '27.7',
#   '2.0',
#   '',
#   '405',
#   '15',
#   ''],
#  ['冷凍蔥油餅',
#   '258',
#   '9.1',
#   '3.1',
#   '1.2',
#   '48.5',
#   '1.3',
#   '2.4',
#   '602',
#   '9',
#   '31.01'],
#  ['冷凍蛋餅皮', '231', '5.7', '3.7', '1.4', '43.7', '1.3', '4.4', '291', '4', ''],
#  ['冷凍燒賣', '188', '9.9', '9.7', '3.4', '15.3', '2.2', '', '384', '24', ''],
#  ['冷凍水晶包', '211', '4.8', '7.8', '3.0', '30.4', '1.5', '', '193', '18', ''],
#  ['冷凍,水晶餃', '190', '2.8', '3.5', '1.5', '36.8', '0.7', '0.2', '348', '0', ''],
#  ['冷凍春捲', '272', '5.1', '13.9', '2.7', '31.5', '2.8', '', '449', '', ''],
#  ['冷凍可樂餅(奶汁)', '114', '3.6', '2.3', '1.5', '19.8', '1.1', '', '338', '7', ''],
#  ['冷凍甘薯條',
#   '182',
#   '1.8',
#   '6.5',
#   '1.6',
#   '29.0',
#   '3.5',
#   '16.9',
#   '67',
#   '',
#   '33.84'],
#  ['冷凍馬鈴薯條',
#   '151',
#   '2.2',
#   '4.5',
#   '1.2',
#   '25.5',
#   '3.5',
#   '0.0',
#   '18',
#   '0',
#   '18.51'],
#  ['冷凍洋蔥圈',
#   '281',
#   '4.0',
#   '11.0',
#   '2.4',
#   '41.4',
#   '2.8',
#   '4.0',
#   '503',
#   '0',
#   '77.66'],
#  ['冷凍豆腐', '131', '12.9', '7.1', '1.3', '3.9', '2.2', '0.6', '8', '', '7.62'],
#  ['冷凍素雞塊', '206', '14.2', '8.1', '1.3', '19.0', '1.2', '', '456', '', ''],
#  ['冷凍小香腸', '249', '14.8', '17.8', '7.0', '7.4', '0.4', '', '722', '46', ''],
#  ['冷凍珍珠丸',
#   '225',
#   '9.5',
#   '11.5',
#   '4.0',
#   '20.9',
#   '1.0',
#   '2.1',
#   '313',
#   '37',
#   '63.17'],
#  ['冷凍貢丸', '244', '16.6', '20.3', '7.4', '0.0', '', '1.5', '580', '42', '93.94'],
#  ['冷凍雞肉丸', '202', '10.5', '12.3', '4.3', '12.3', '', '', '597', '43', ''],
#  ['冷凍牛肉漢堡肉',
#   '249',
#   '14.4',
#   '18.5',
#   '9.3',
#   '6.3',
#   '1.5',
#   '0.0',
#   '302',
#   '66',
#   ''],
#  ['冷凍雞塊',
#   '228',
#   '15.3',
#   '12.9',
#   '5.5',
#   '12.6',
#   '',
#   '2.1',
#   '596',
#   '33',
#   '99.50'],
#  ['冷凍咕咾肉', '184', '6.4', '9.5', '2.5', '18.3', '1.5', '', '395', '22', ''],
#  ['冷凍花枝丸', '166', '12.7', '7.0', '2.7', '13.0', '1.9', '2.6', '456', '113', ''],
#  ['冷凍虱目魚丸',
#   '206',
#   '13.7',
#   '11.9',
#   '4.4',
#   '11.0',
#   '1.5',
#   '4.5',
#   '551',
#   '39',
#   ''],
#  ['冷凍文蛤丸', '211', '16.2', '9.2', '3.4', '15.8', '', '', '565', '65', ''],
#  ['冷凍旗魚丸', '160', '12.8', '6.7', '2.5', '12.0', '0.8', '4.9', '700', '30', ''],
#  ['冷凍鱈魚丸', '99', '8.5', '2.4', '1.0', '10.7', '', '3.9', '459', '11', '52.70'],
#  ['冷凍蝦丸', '123', '10.8', '2.3', '0.9', '14.7', '', '', '780', '35', ''],
#  ['冷凍花枝排', '187', '5.5', '7.3', '2.7', '24.9', '1.3', '3.2', '648', '18', ''],
#  ['冷凍鮪排', '143', '13.4', '0.9', '0.3', '20.4', '', '', '664', '120', ''],
#  ['冷凍蝦餅', '127', '9.6', '2.1', '0.5', '17.3', '1.6', '', '337', '50', ''],
#  ['冷凍干貝酥', '146', '8.3', '0.2', '0.1', '27.7', '1.0', '', '802', '8', ''],
#  ['冷凍花枝塊', '180', '11.3', '7.5', '1.5', '17.0', '0.8', '', '508', '82', ''],
#  ['冷凍旗魚塊', '178', '15.3', '6.5', '1.3', '14.7', '', '', '423', '76', ''],
#  ['冷凍蚵捲',
#   '213',
#   '6.9',
#   '17.5',
#   '6.6',
#   '7.0',
#   '2.3',
#   '4.1',
#   '463',
#   '17',
#   '70.37'],
#  ['冷凍魚捲', '126', '13.8', '0.3', '', '17.1', '0.7', '', '401', '', ''],
#  ['冷凍蝦捲', '156', '10.3', '5.7', '2.0', '16.0', '1.4', '2.7', '667', '75', ''],
#  ['冷凍魷魚圈', '143', '15.7', '0.4', '', '19.2', '', '', '443', '', ''],
#  ['冷凍花枝餃',
#   '177',
#   '12.4',
#   '5.6',
#   '2.1',
#   '19.2',
#   '',
#   '2.8',
#   '723',
#   '22',
#   '27.03'],
#  ['冷凍香菇餃', '233', '12.3', '15.3', '5.7', '11.5', '1.1', '', '673', '39', ''],
#  ['冷凍蛋餃',
#   '183',
#   '12.1',
#   '14.1',
#   '5.1',
#   '2.1',
#   '0.5',
#   '1.3',
#   '472',
#   '246',
#   '51.58'],
#  ['冷凍雪螺餃', '204', '11.6', '10.0', '3.1', '16.7', '1.1', '', '788', '33', ''],
#  ['冷凍魚餃',
#   '277',
#   '12.5',
#   '19.5',
#   '8.6',
#   '12.9',
#   '',
#   '1.2',
#   '663',
#   '60',
#   '75.56'],
#  ['冷凍蝦餃', '273', '11.4', '19.3', '7.2', '13.5', '', '', '622', '72', ''],
#  ['冷凍燕餃',
#   '321',
#   '12.8',
#   '23.6',
#   '9.0',
#   '14.5',
#   '',
#   '1.7',
#   '604',
#   '53',
#   '142.94'],
#  ['冷凍蟹味棒', '118', '9.3', '0.7', '0.2', '18.6', '', '3.1', '694', '', '4.80'],
#  ['冷凍魚卵卷', '115', '12.9', '0.2', '0.1', '15.5', '', '3.7', '830', '28', '6.32'],
#  ['冷凍花枝漿',
#   '227',
#   '11.2',
#   '12.6',
#   '4.5',
#   '17.1',
#   '2.0',
#   '1.8',
#   '637',
#   '188',
#   ''],
#  ['冷凍花枝羹', '126', '11.4', '4.7', '1.8', '9.4', '', '', '448', '80', ''],
#  ['冷凍烤雞翅', '217', '18.8', '14.2', '3.9', '3.6', '', '', '509', '109', '']]

# %% [markdown]
# ## Convert to Dataframe Graph & Save as CSV

# %%
import pandas as pd

selected_items = []
selected_items = ["熱量", "粗蛋白", "粗脂肪", "飽和脂肪", "總碳水化合物", "膳食纖維", "糖質總量", "鈉", "膽固醇", "反式脂肪"]
selected_items.insert(0,"樣品名稱")
selected_items
# Out:
# ['樣品名稱',
#  '熱量',
#  '粗蛋白',
#  '粗脂肪',
#  '飽和脂肪',
#  '總碳水化合物',
#  '膳食纖維',
#  '糖質總量',
#  '鈉',
#  '膽固醇',
#  '反式脂肪']

# %%
df = pd.DataFrame(food_nutr, columns=selected_items)
df
# Out:
#       樣品名稱   熱量   粗蛋白   粗脂肪 飽和脂肪 總碳水化合物 膳食纖維 糖質總量    鈉  膽固醇   反式脂肪
# 0   冷凍火腿炒飯  189   5.0   5.6  1.1   29.7  2.0       220   37
# 1   冷凍蝦仁炒飯  148   4.7   3.4  0.5   24.6  2.7  1.3  222   11  13.41
# 2   冷凍筒仔米糕  212   6.5   5.8  2.2   33.6  0.7       331   13
# 3   冷凍芝麻湯圓  352   4.8  16.3  6.6   46.7  0.9  9.7    3    0  69.29
# 4   冷凍花生湯圓  350   5.2  15.6  7.3   47.1  0.6  9.8    6    0  66.28
# ..     ...  ...   ...   ...  ...    ...  ...  ...  ...  ...    ...
# 75   冷凍蟹味棒  118   9.3   0.7  0.2   18.6       3.1  694        4.80
# 76   冷凍魚卵卷  115  12.9   0.2  0.1   15.5       3.7  830   28   6.32
# 77   冷凍花枝漿  227  11.2  12.6  4.5   17.1  2.0  1.8  637  188
# 78   冷凍花枝羹  126  11.4   4.7  1.8    9.4            448   80
# 79   冷凍烤雞翅  217  18.8  14.2  3.9    3.6            509  109
#
# [80 rows x 11 columns]

# %%
df.shape
# Out:
# (80, 11)

# %%
df.to_csv('FrozenFood_ExtractedNutrInfo.csv', index=False)

# %% [markdown]
# ## 關閉分頁及browser

# %%
# 讀最後一頁開始，把所有分頁關掉 (初始頁要保留)
while len(driver.window_handles) > 1:
    #change tabs
    driver.switch_to.window(
        driver.window_handles[ len(driver.window_handles) - 1 ]
    )

    #close tabs
    driver.close()

# %%
#close browser
driver.quit()
